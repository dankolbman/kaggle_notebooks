# %%
import os
import numpy as np
import pandas as pd
from sklearn import preprocessing, manifold, ensemble
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb

# %matplotlib inline

# %%
train_dat = pd.read_csv('features/zeros_ones_train.csv')
test_dat = pd.read_csv('features/zeros_ones_test.csv')
train_labels = np.load('features/train_labels.npy')
train_dat.head()
# Out:
#    Field6  Field7  Field8  Field9  Field10  Field11  Field12  CoverageField1A  \
# 0       1      23  0.9403  0.0006        7   1.0200        0               17
# 1       5       7  1.0006  0.0040        4   1.2433        0                6
# 2       5       7  1.0006  0.0040        4   1.2433        0                7
# 3       6      10  0.9769  0.0004        1   1.2665        0                3
# 4       4      23  0.9472  0.0006        3   1.3045        0                8
#
#    CoverageField1B  CoverageField2A   ...     GeographicField60B  \
# 0               23               17   ...                      8
# 1                8                6   ...                     11
# 2               12                7   ...                     21
# 3                2                3   ...                     10
# 4               13                8   ...                     10
#
#    GeographicField61A  GeographicField61B  GeographicField62A  \
# 0                  -1                  18                  -1
# 1                  -1                  17                  -1
# 2                  -1                  11                  -1
# 3                  -1                   9                  -1
# 4                  -1                  11                  -1
#
#    GeographicField62B  GeographicField63  GeographicField64  Month  Year  \
# 0                  10                  1                  0      8  2013
# 1                  20                  1                  2      4  2014
# 2                   8                  1                  2      8  2014
# 3                  21                  1                  3      4  2013
# 4                  12                  1                  1      1  2014
#
#    Weekday
# 0        4
# 1        1
# 2        0
# 3        0
# 4        5
#
# [5 rows x 299 columns]

# %%
base = xgb.XGBClassifier(nthread=4)

clf = ensemble.BaggingClassifier(base, n_estimators=10, max_samples=1.0, max_features=1.0)
N = int(0.5*len(train_labels))
clf.fit(train_dat.iloc[0:N], train_labels[0:N])

# %%
clf.score(train_dat.iloc[N:], train_labels[N:])

# %% [markdown]
# # Bagging

# %%
bags = 50
bag_ratio = 0.85
models = []
N = int(0.9*len(train_dat))

xg_test = xgb.DMatrix( train_dat.iloc[N:].as_matrix(), label=train_labels[N:])

X = train_dat.iloc[:N]
Y = train_labels[:N]

param = {   'objective': 'binary:logistic',
            'eval_metric': 'auc',
            'nthread':4,
            'max_depth':6,
            'colsample_bytree':0.77,
            'subsample':0.85,
            'min_child_weight':4,
            'eta':0.02,
        }
num_round = 1000

for i in range(bags):
    print('\rBag {} of {}'.format(i+1,bags),end='')
    
    r = np.random.rand(X.shape[0])
    X_bag = X[r<bag_ratio]
    Y_bag = Y[r<bag_ratio]
    xg_train = xgb.DMatrix( X_bag.as_matrix(), label=Y_bag)
    
    watchlist = [(xg_train,'train'),(xg_test,'eval')]
    model = xgb.train(param, xg_train, num_round, watchlist,
                      early_stopping_rounds=100)
    model.save_model('bag_models/model{}'.format(i+49))
    models.append(model)
    del xg_train
# Out:
# Will train until train error hasn't decreased in 100 rounds.
# [0]	eval-auc:0.905343	train-auc:0.903531
# [1]	eval-auc:0.935870	train-auc:0.934311
# [2]	eval-auc:0.937232	train-auc:0.935070
# [3]	eval-auc:0.939361	train-auc:0.936913
# [4]	eval-auc:0.940755	train-auc:0.938322
# [5]	eval-auc:0.941774	train-auc:0.939605
# [6]	eval-auc:0.941790	train-auc:0.939567
# [7]	eval-auc:0.942111	train-auc:0.940042
# [8]	eval-auc:0.942891	train-auc:0.940879
# [9]	eval-auc:0.943295	train-auc:0.941058
# [10]	eval-auc:0.943547	train-auc:0.941161
# [11]	eval-auc:0.945002	train-auc:0.942518
# [12]	eval-auc:0.945938	train-auc:0.943730
# [13]	eval-auc:0.945838	train-auc:0.943702
# [14]	eval-auc:0.945830	train-auc:0.943718
# [15]	eval-auc:0.946022	train-auc:0.943961
# [16]	eval-auc:0.946070	train-auc:0.943945
# [17]	eval-auc:0.945991	train-auc:0.943832
# [18]	eval-auc:0.946135	train-auc:0.943979
# [19]	eval-auc:0.946338	train-auc:0.944152
# [20]	eval-auc:0.946342	train-auc:0.944192
# [21]	eval-auc:0.946562	train-auc:0.944345
# [22]	eval-auc:0.946510	train-auc:0.944383
# [23]	eval-auc:0.946799	train-auc:0.944770
# [24]	eval-auc:0.946794	train-auc:0.944738
# [25]	eval-auc:0.946856	train-auc:0.944826
# [26]	eval-auc:0.947059	train-auc:0.944995
# [27]	eval-auc:0.947098	train-auc:0.945024
# [28]	eval-auc:0.947365	train-auc:0.945308
# [29]	eval-auc:0.947638	train-auc:0.945589
# [30]	eval-auc:0.947691	train-auc:0.945620
# [31]	eval-auc:0.947951	train-auc:0.945874
# [32]	eval-auc:0.948036	train-auc:0.945900
# [33]	eval-auc:0.948145	train-auc:0.945966
# [34]	eval-auc:0.948174	train-auc:0.946004
# [35]	eval-auc:0.948167	train-auc:0.945977
# [36]	eval-auc:0.948195	train-auc:0.945982
# [37]	eval-auc:0.948178	train-auc:0.945952
# [38]	eval-auc:0.948262	train-auc:0.946055
# [39]	eval-auc:0.948238	train-auc:0.946024
# [40]	eval-auc:0.948177	train-auc:0.946001
# [41]	eval-auc:0.948202	train-auc:0.945997
# [42]	eval-auc:0.948468	train-auc:0.946331
# [43]	eval-auc:0.948479	train-auc:0.946373
# [44]	eval-auc:0.948438	train-auc:0.946343
# [45]	eval-auc:0.948576	train-auc:0.946535
# [46]	eval-auc:0.948756	train-auc:0.946719
# [47]	eval-auc:0.948796	train-auc:0.946747
# [48]	eval-auc:0.948796	train-auc:0.946778
# [49]	eval-auc:0.949032	train-auc:0.947035
# [50]	eval-auc:0.948982	train-auc:0.947016
# [51]	eval-auc:0.949240	train-auc:0.947247
# [52]	eval-auc:0.949423	train-auc:0.947449
# [53]	eval-auc:0.949666	train-auc:0.947714
# [54]	eval-auc:0.949672	train-auc:0.947723
# [55]	eval-auc:0.949670	train-auc:0.947702
# [56]	eval-auc:0.949661	train-auc:0.947691
# [57]	eval-auc:0.949706	train-auc:0.947710
# [58]	eval-auc:0.949679	train-auc:0.947702
# [59]	eval-auc:0.949818	train-auc:0.947838
# [60]	eval-auc:0.949819	train-auc:0.947856
# [61]	eval-auc:0.949896	train-auc:0.947908
# [62]	eval-auc:0.949868	train-auc:0.947904
# [63]	eval-auc:0.949936	train-auc:0.947972
# [64]	eval-auc:0.949903	train-auc:0.947964
# [65]	eval-auc:0.949985	train-auc:0.948025
# [66]	eval-auc:0.950172	train-auc:0.948240
# [67]	eval-auc:0.950509	train-auc:0.948627
# [68]	eval-auc:0.950494	train-auc:0.948625
# [69]	eval-auc:0.950622	train-auc:0.948771
# [70]	eval-auc:0.950662	train-auc:0.948838
# [71]	eval-auc:0.950747	train-auc:0.948939
# [72]	eval-auc:0.950812	train-auc:0.949017
# [73]	eval-auc:0.950840	train-auc:0.949037
# [74]	eval-auc:0.950983	train-auc:0.949178
# [75]	eval-auc:0.950953	train-auc:0.949195
# [76]	eval-auc:0.951017	train-auc:0.949262
# [77]	eval-auc:0.951035	train-auc:0.949291
# [78]	eval-auc:0.951178	train-auc:0.949470
# [79]	eval-auc:0.951266	train-auc:0.949534
# [80]	eval-auc:0.951272	train-auc:0.949554
# [81]	eval-auc:0.951308	train-auc:0.949594
# [82]	eval-auc:0.951361	train-auc:0.949657
# [83]	eval-auc:0.951478	train-auc:0.949785
# [84]	eval-auc:0.951526	train-auc:0.949831
# [85]	eval-auc:0.951536	train-auc:0.949832
# [86]	eval-auc:0.951629	train-auc:0.949935
# [87]	eval-auc:0.951678	train-auc:0.949984
# [88]	eval-auc:0.951813	train-auc:0.950116
# [89]	eval-auc:0.951832	train-auc:0.950127
# [90]	eval-auc:0.951826	train-auc:0.950142
# [91]	eval-auc:0.951974	train-auc:0.950282
# [92]	eval-auc:0.952001	train-auc:0.950317
# [93]	eval-auc:0.952107	train-auc:0.950434
# [94]	eval-auc:0.952214	train-auc:0.950532
# [95]	eval-auc:0.952288	train-auc:0.950620
# [96]	eval-auc:0.952310	train-auc:0.950644
# [97]	eval-auc:0.952403	train-auc:0.950723
# [98]	eval-auc:0.952471	train-auc:0.950828
# [99]	eval-auc:0.952593	train-auc:0.950951
# [100]	eval-auc:0.952658	train-auc:0.950984
# [101]	eval-auc:0.952642	train-auc:0.950981
# [102]	eval-auc:0.952660	train-auc:0.951020
# [103]	eval-auc:0.952699	train-auc:0.951042
# [104]	eval-auc:0.952771	train-auc:0.951110
# [105]	eval-auc:0.953008	train-auc:0.951392
# [106]	eval-auc:0.953054	train-auc:0.951445
# [107]	eval-auc:0.953204	train-auc:0.951607
# [108]	eval-auc:0.953443	train-auc:0.951872
# [109]	eval-auc:0.953452	train-auc:0.951904
# [110]	eval-auc:0.953448	train-auc:0.951921
# [111]	eval-auc:0.953557	train-auc:0.952018
# [112]	eval-auc:0.953594	train-auc:0.952041
# [113]	eval-auc:0.953634	train-auc:0.952068
# [114]	eval-auc:0.953688	train-auc:0.952108
# [115]	eval-auc:0.953773	train-auc:0.952205
# [116]	eval-auc:0.953818	train-auc:0.952260
# [117]	eval-auc:0.953867	train-auc:0.952324
# [118]	eval-auc:0.953921	train-auc:0.952380
# [119]	eval-auc:0.954063	train-auc:0.952549
# [120]	eval-auc:0.954254	train-auc:0.952773
# [121]	eval-auc:0.954348	train-auc:0.952886
# [122]	eval-auc:0.954365	train-auc:0.952898
# [123]	eval-auc:0.954382	train-auc:0.952919
# [124]	eval-auc:0.954380	train-auc:0.952929
# [125]	eval-auc:0.954440	train-auc:0.953001
# [126]	eval-auc:0.954506	train-auc:0.953083
# [127]	eval-auc:0.954526	train-auc:0.953120
# [128]	eval-auc:0.954646	train-auc:0.953257
# [129]	eval-auc:0.954656	train-auc:0.953262
# [130]	eval-auc:0.954763	train-auc:0.953405
# [131]	eval-auc:0.954758	train-auc:0.953423
# [132]	eval-auc:0.954861	train-auc:0.953536
# [133]	eval-auc:0.954921	train-auc:0.953597
# [134]	eval-auc:0.955023	train-auc:0.953710
# [135]	eval-auc:0.955175	train-auc:0.953889
# [136]	eval-auc:0.955193	train-auc:0.953922
# [137]	eval-auc:0.955194	train-auc:0.953929
# [138]	eval-auc:0.955200	train-auc:0.953954
# [139]	eval-auc:0.955312	train-auc:0.954077
# [140]	eval-auc:0.955364	train-auc:0.954145
# [141]	eval-auc:0.955494	train-auc:0.954307
# [142]	eval-auc:0.955532	train-auc:0.954362
# [143]	eval-auc:0.955546	train-auc:0.954376
# [144]	eval-auc:0.955539	train-auc:0.954370
# [145]	eval-auc:0.955611	train-auc:0.954446
# [146]	eval-auc:0.955645	train-auc:0.954496
# [147]	eval-auc:0.955643	train-auc:0.954498
# [148]	eval-auc:0.955736	train-auc:0.954603
# [149]	eval-auc:0.955743	train-auc:0.954635
# [150]	eval-auc:0.955881	train-auc:0.954790
# [151]	eval-auc:0.956064	train-auc:0.955006
# [152]	eval-auc:0.956110	train-auc:0.955055
# [153]	eval-auc:0.956127	train-auc:0.955078
# [154]	eval-auc:0.956172	train-auc:0.955124
# [155]	eval-auc:0.956188	train-auc:0.955153
# [156]	eval-auc:0.956245	train-auc:0.955206
# [157]	eval-auc:0.956328	train-auc:0.955295
# [158]	eval-auc:0.956350	train-auc:0.955319
# [159]	eval-auc:0.956356	train-auc:0.955320
# [160]	eval-auc:0.956498	train-auc:0.955494
# [161]	eval-auc:0.956507	train-auc:0.955518
# [162]	eval-auc:0.956617	train-auc:0.955644
# [163]	eval-auc:0.956642	train-auc:0.955679
# [164]	eval-auc:0.956708	train-auc:0.955745
# [165]	eval-auc:0.956750	train-auc:0.955796
# [166]	eval-auc:0.956803	train-auc:0.955844
# [167]	eval-auc:0.956826	train-auc:0.955876
# [168]	eval-auc:0.956871	train-auc:0.955935
# [169]	eval-auc:0.956936	train-auc:0.956008
# [170]	eval-auc:0.957058	train-auc:0.956142
# [171]	eval-auc:0.957181	train-auc:0.956269
# [172]	eval-auc:0.957203	train-auc:0.956290
# [173]	eval-auc:0.957248	train-auc:0.956354
# [174]	eval-auc:0.957308	train-auc:0.956427
# [175]	eval-auc:0.957340	train-auc:0.956474
# [176]	eval-auc:0.957424	train-auc:0.956575
# [177]	eval-auc:0.957460	train-auc:0.956607
# [178]	eval-auc:0.957507	train-auc:0.956682
# [179]	eval-auc:0.957533	train-auc:0.956720
# [180]	eval-auc:0.957547	train-auc:0.956734
# [181]	eval-auc:0.957603	train-auc:0.956786
# [182]	eval-auc:0.957667	train-auc:0.956843
# [183]	eval-auc:0.957702	train-auc:0.956887
# [184]	eval-auc:0.957743	train-auc:0.956936
# [185]	eval-auc:0.957870	train-auc:0.957078
# [186]	eval-auc:0.957886	train-auc:0.957087
# [187]	eval-auc:0.957922	train-auc:0.957137
# [188]	eval-auc:0.957942	train-auc:0.957164
# [189]	eval-auc:0.957963	train-auc:0.957192
# [190]	eval-auc:0.958071	train-auc:0.957308
# [191]	eval-auc:0.958084	train-auc:0.957319
# [192]	eval-auc:0.958120	train-auc:0.957344
# [193]	eval-auc:0.958155	train-auc:0.957375
# [194]	eval-auc:0.958194	train-auc:0.957425
# [195]	eval-auc:0.958296	train-auc:0.957552
# [196]	eval-auc:0.958335	train-auc:0.957596
# [197]	eval-auc:0.958373	train-auc:0.957645
# [198]	eval-auc:0.958411	train-auc:0.957697
# [199]	eval-auc:0.958420	train-auc:0.957708
# [200]	eval-auc:0.958446	train-auc:0.957740
# [201]	eval-auc:0.958537	train-auc:0.957847
# [202]	eval-auc:0.958559	train-auc:0.957881
# [203]	eval-auc:0.958587	train-auc:0.957917
# [204]	eval-auc:0.958606	train-auc:0.957949
# [205]	eval-auc:0.958627	train-auc:0.957980
# [206]	eval-auc:0.958779	train-auc:0.958118
# [207]	eval-auc:0.958801	train-auc:0.958141
# [208]	eval-auc:0.958848	train-auc:0.958195
# [209]	eval-auc:0.958873	train-auc:0.958218
# [210]	eval-auc:0.958986	train-auc:0.958340
# [211]	eval-auc:0.959002	train-auc:0.958365
# [212]	eval-auc:0.959098	train-auc:0.958468
# [213]	eval-auc:0.959102	train-auc:0.958491
# [214]	eval-auc:0.959104	train-auc:0.958500
# [215]	eval-auc:0.959159	train-auc:0.958560
# [216]	eval-auc:0.959175	train-auc:0.958581
# [217]	eval-auc:0.959255	train-auc:0.958667
# [218]	eval-auc:0.959260	train-auc:0.958678
# [219]	eval-auc:0.959288	train-auc:0.958713
# [220]	eval-auc:0.959371	train-auc:0.958809
# [221]	eval-auc:0.959447	train-auc:0.958891
# [222]	eval-auc:0.959466	train-auc:0.958910
# [223]	eval-auc:0.959472	train-auc:0.958928
# [224]	eval-auc:0.959491	train-auc:0.958949
# [225]	eval-auc:0.959515	train-auc:0.958988
# [226]	eval-auc:0.959525	train-auc:0.959006
# [227]	eval-auc:0.959534	train-auc:0.959013
# [228]	eval-auc:0.959542	train-auc:0.959021
# [229]	eval-auc:0.959612	train-auc:0.959094
# [230]	eval-auc:0.959668	train-auc:0.959162
# [231]	eval-auc:0.959709	train-auc:0.959214
# [232]	eval-auc:0.959720	train-auc:0.959229
# [233]	eval-auc:0.959771	train-auc:0.959287
# [234]	eval-auc:0.959795	train-auc:0.959319
# [235]	eval-auc:0.959826	train-auc:0.959354
# [236]	eval-auc:0.959854	train-auc:0.959392
# [237]	eval-auc:0.959877	train-auc:0.959423
# [238]	eval-auc:0.959978	train-auc:0.959530
# [239]	eval-auc:0.960012	train-auc:0.959562
# [240]	eval-auc:0.960030	train-auc:0.959589
# [241]	eval-auc:0.960082	train-auc:0.959664
# [242]	eval-auc:0.960115	train-auc:0.959710
# [243]	eval-auc:0.960130	train-auc:0.959726
# [244]	eval-auc:0.960206	train-auc:0.959814
# [245]	eval-auc:0.960250	train-auc:0.959876
# [246]	eval-auc:0.960286	train-auc:0.959915
# [247]	eval-auc:0.960311	train-auc:0.959944
# [248]	eval-auc:0.960366	train-auc:0.960016
# [249]	eval-auc:0.960373	train-auc:0.960031
# [250]	eval-auc:0.960388	train-auc:0.960060
# [251]	eval-auc:0.960397	train-auc:0.960071
# [252]	eval-auc:0.960399	train-auc:0.960081
# [253]	eval-auc:0.960500	train-auc:0.960178
# [254]	eval-auc:0.960511	train-auc:0.960208
# [255]	eval-auc:0.960530	train-auc:0.960234
# [256]	eval-auc:0.960569	train-auc:0.960302
# [257]	eval-auc:0.960593	train-auc:0.960323
# [258]	eval-auc:0.960619	train-auc:0.960346
# [259]	eval-auc:0.960679	train-auc:0.960422
# [260]	eval-auc:0.960713	train-auc:0.960466
# [261]	eval-auc:0.960725	train-auc:0.960494
# [262]	eval-auc:0.960750	train-auc:0.960527
# [263]	eval-auc:0.960758	train-auc:0.960552
# [264]	eval-auc:0.960810	train-auc:0.960610
# [265]	eval-auc:0.960884	train-auc:0.960711
# [266]	eval-auc:0.960911	train-auc:0.960754
# [267]	eval-auc:0.960923	train-auc:0.960766
# [268]	eval-auc:0.960936	train-auc:0.960783
# [269]	eval-auc:0.960951	train-auc:0.960810
# [270]	eval-auc:0.960994	train-auc:0.960858
# [271]	eval-auc:0.961006	train-auc:0.960887
# [272]	eval-auc:0.961018	train-auc:0.960914
# [273]	eval-auc:0.961047	train-auc:0.960965
# [274]	eval-auc:0.961067	train-auc:0.960989
# [275]	eval-auc:0.961087	train-auc:0.961016
# [276]	eval-auc:0.961138	train-auc:0.961077
# [277]	eval-auc:0.961195	train-auc:0.961134
# [278]	eval-auc:0.961211	train-auc:0.961160
# [279]	eval-auc:0.961262	train-auc:0.961253
# [280]	eval-auc:0.961274	train-auc:0.961278
# [281]	eval-auc:0.961291	train-auc:0.961310
# [282]	eval-auc:0.961326	train-auc:0.961350
# [283]	eval-auc:0.961347	train-auc:0.961385
# [284]	eval-auc:0.961399	train-auc:0.961460
# [285]	eval-auc:0.961420	train-auc:0.961501
# [286]	eval-auc:0.961425	train-auc:0.961510
# [287]	eval-auc:0.961446	train-auc:0.961534
# [288]	eval-auc:0.961455	train-auc:0.961549
# [289]	eval-auc:0.961470	train-auc:0.961572
# [290]	eval-auc:0.961521	train-auc:0.961639
# [291]	eval-auc:0.961538	train-auc:0.961667
# [292]	eval-auc:0.961542	train-auc:0.961691
# [293]	eval-auc:0.961562	train-auc:0.961726
# [294]	eval-auc:0.961654	train-auc:0.961823
# [295]	eval-auc:0.961730	train-auc:0.961916
# [296]	eval-auc:0.961734	train-auc:0.961934
# [297]	eval-auc:0.961785	train-auc:0.962006
# [298]	eval-auc:0.961847	train-auc:0.962092
# [299]	eval-auc:0.961864	train-auc:0.962138
# [300]	eval-auc:0.961880	train-auc:0.962157
# [301]	eval-auc:0.961911	train-auc:0.962202
# [302]	eval-auc:0.961968	train-auc:0.962264
# [303]	eval-auc:0.961987	train-auc:0.962291
# [304]	eval-auc:0.962003	train-auc:0.962315
# [305]	eval-auc:0.962022	train-auc:0.962342
# [306]	eval-auc:0.962062	train-auc:0.962390
# [307]	eval-auc:0.962077	train-auc:0.962422
# [308]	eval-auc:0.962115	train-auc:0.962478
# [309]	eval-auc:0.962119	train-auc:0.962488
# [310]	eval-auc:0.962149	train-auc:0.962541
# [311]	eval-auc:0.962189	train-auc:0.962590
# [312]	eval-auc:0.962207	train-auc:0.962621
# [313]	eval-auc:0.962221	train-auc:0.962641
# [314]	eval-auc:0.962260	train-auc:0.962694
# [315]	eval-auc:0.962293	train-auc:0.962750
# [316]	eval-auc:0.962302	train-auc:0.962763
# [317]	eval-auc:0.962318	train-auc:0.962784
# [318]	eval-auc:0.962346	train-auc:0.962850
# [319]	eval-auc:0.962371	train-auc:0.962897
# [320]	eval-auc:0.962442	train-auc:0.962988
# [321]	eval-auc:0.962466	train-auc:0.963025
# [322]	eval-auc:0.962467	train-auc:0.963034
# [323]	eval-auc:0.962496	train-auc:0.963073
# [324]	eval-auc:0.962538	train-auc:0.963134
# [325]	eval-auc:0.962564	train-auc:0.963172
# [326]	eval-auc:0.962592	train-auc:0.963214
# [327]	eval-auc:0.962596	train-auc:0.963228
# [328]	eval-auc:0.962619	train-auc:0.963262
# [329]	eval-auc:0.962642	train-auc:0.963305
# [330]	eval-auc:0.962649	train-auc:0.963318
# [331]	eval-auc:0.962720	train-auc:0.963392
# [332]	eval-auc:0.962738	train-auc:0.963408
# [333]	eval-auc:0.962753	train-auc:0.963432
# [334]	eval-auc:0.962808	train-auc:0.963489
# [335]	eval-auc:0.962843	train-auc:0.963550
# [336]	eval-auc:0.962855	train-auc:0.963599
# [337]	eval-auc:0.962871	train-auc:0.963610
# [338]	eval-auc:0.962887	train-auc:0.963646
# [339]	eval-auc:0.962889	train-auc:0.963653
# [340]	eval-auc:0.962908	train-auc:0.963689
# [341]	eval-auc:0.962927	train-auc:0.963710
# [342]	eval-auc:0.962935	train-auc:0.963719
# [343]	eval-auc:0.962978	train-auc:0.963780
# [344]	eval-auc:0.962991	train-auc:0.963801
# [345]	eval-auc:0.963012	train-auc:0.963852
# [346]	eval-auc:0.963021	train-auc:0.963875
# [347]	eval-auc:0.963082	train-auc:0.963941
# [348]	eval-auc:0.963103	train-auc:0.963979
# [349]	eval-auc:0.963136	train-auc:0.964026
# [350]	eval-auc:0.963169	train-auc:0.964082
# [351]	eval-auc:0.963192	train-auc:0.964115
# [352]	eval-auc:0.963233	train-auc:0.964166
# [353]	eval-auc:0.963248	train-auc:0.964197
# [354]	eval-auc:0.963261	train-auc:0.964233
# [355]	eval-auc:0.963277	train-auc:0.964267
# [356]	eval-auc:0.963293	train-auc:0.964298
# [357]	eval-auc:0.963305	train-auc:0.964321
# [358]	eval-auc:0.963318	train-auc:0.964349
# [359]	eval-auc:0.963348	train-auc:0.964388
# [360]	eval-auc:0.963358	train-auc:0.964414
# [361]	eval-auc:0.963365	train-auc:0.964430
# [362]	eval-auc:0.963389	train-auc:0.964476
# [363]	eval-auc:0.963396	train-auc:0.964493
# [364]	eval-auc:0.963406	train-auc:0.964503
# [365]	eval-auc:0.963460	train-auc:0.964570
# [366]	eval-auc:0.963483	train-auc:0.964611
# [367]	eval-auc:0.963537	train-auc:0.964669
# [368]	eval-auc:0.963556	train-auc:0.964702
# [369]	eval-auc:0.963568	train-auc:0.964733
# [370]	eval-auc:0.963587	train-auc:0.964765
# [371]	eval-auc:0.963605	train-auc:0.964786
# [372]	eval-auc:0.963613	train-auc:0.964811
# [373]	eval-auc:0.963622	train-auc:0.964841
# [374]	eval-auc:0.963633	train-auc:0.964866
# [375]	eval-auc:0.963654	train-auc:0.964905
# [376]	eval-auc:0.963681	train-auc:0.964928
# [377]	eval-auc:0.963695	train-auc:0.964942
# [378]	eval-auc:0.963746	train-auc:0.964994
# [379]	eval-auc:0.963754	train-auc:0.965017
# [380]	eval-auc:0.963765	train-auc:0.965030
# [381]	eval-auc:0.963766	train-auc:0.965043
# [382]	eval-auc:0.963770	train-auc:0.965059
# [383]	eval-auc:0.963784	train-auc:0.965098
# [384]	eval-auc:0.963831	train-auc:0.965147
# [385]	eval-auc:0.963838	train-auc:0.965160
# [386]	eval-auc:0.963869	train-auc:0.965201
# [387]	eval-auc:0.963878	train-auc:0.965231
# [388]	eval-auc:0.963885	train-auc:0.965250
# [389]	eval-auc:0.963893	train-auc:0.965260
# [390]	eval-auc:0.963909	train-auc:0.965290
# [391]	eval-auc:0.963919	train-auc:0.965323
# [392]	eval-auc:0.963933	train-auc:0.965349
# [393]	eval-auc:0.963949	train-auc:0.965383
# [394]	eval-auc:0.963959	train-auc:0.965415
# [395]	eval-auc:0.963970	train-auc:0.965442
# [396]	eval-auc:0.964018	train-auc:0.965495
# [397]	eval-auc:0.964045	train-auc:0.965530
# [398]	eval-auc:0.964055	train-auc:0.965554
# [399]	eval-auc:0.964064	train-auc:0.965585
# [400]	eval-auc:0.964074	train-auc:0.965621
# [401]	eval-auc:0.964087	train-auc:0.965640
# [402]	eval-auc:0.964107	train-auc:0.965678
# [403]	eval-auc:0.964115	train-auc:0.965692
# [404]	eval-auc:0.964120	train-auc:0.965708
# [405]	eval-auc:0.964152	train-auc:0.965760
# [406]	eval-auc:0.964158	train-auc:0.965784
# [407]	eval-auc:0.964164	train-auc:0.965803
# [408]	eval-auc:0.964171	train-auc:0.965825
# [409]	eval-auc:0.964191	train-auc:0.965861
# [410]	eval-auc:0.964204	train-auc:0.965894
# [411]	eval-auc:0.964214	train-auc:0.965915
# [412]	eval-auc:0.964222	train-auc:0.965945
# [413]	eval-auc:0.964237	train-auc:0.965980
# [414]	eval-auc:0.964260	train-auc:0.966021
# [415]	eval-auc:0.964269	train-auc:0.966046
# [416]	eval-auc:0.964292	train-auc:0.966083
# [417]	eval-auc:0.964294	train-auc:0.966094
# [418]	eval-auc:0.964302	train-auc:0.966113
# [419]	eval-auc:0.964319	train-auc:0.966139
# [420]	eval-auc:0.964366	train-auc:0.966183
# [421]	eval-auc:0.964368	train-auc:0.966208
# [422]	eval-auc:0.964381	train-auc:0.966233
# [423]	eval-auc:0.964396	train-auc:0.966261
# [424]	eval-auc:0.964405	train-auc:0.966274
# [425]	eval-auc:0.964413	train-auc:0.966301
# [426]	eval-auc:0.964415	train-auc:0.966327
# [427]	eval-auc:0.964443	train-auc:0.966369
# [428]	eval-auc:0.964451	train-auc:0.966394
# [429]	eval-auc:0.964464	train-auc:0.966429
# [430]	eval-auc:0.964494	train-auc:0.966469
# [431]	eval-auc:0.964496	train-auc:0.966479
# [432]	eval-auc:0.964515	train-auc:0.966512
# [433]	eval-auc:0.964530	train-auc:0.966528
# [434]	eval-auc:0.964540	train-auc:0.966552
# [435]	eval-auc:0.964553	train-auc:0.966576
# [436]	eval-auc:0.964568	train-auc:0.966615
# [437]	eval-auc:0.964581	train-auc:0.966643
# [438]	eval-auc:0.964603	train-auc:0.966680
# [439]	eval-auc:0.964605	train-auc:0.966707
# [440]	eval-auc:0.964611	train-auc:0.966737
# [441]	eval-auc:0.964620	train-auc:0.966764
# [442]	eval-auc:0.964632	train-auc:0.966790
# [443]	eval-auc:0.964633	train-auc:0.966809
# [444]	eval-auc:0.964640	train-auc:0.966833
# [445]	eval-auc:0.964669	train-auc:0.966885
# [446]	eval-auc:0.964672	train-auc:0.966903
# [447]	eval-auc:0.964683	train-auc:0.966925
# [448]	eval-auc:0.964709	train-auc:0.966957
# [449]	eval-auc:0.964715	train-auc:0.966979
# [450]	eval-auc:0.964715	train-auc:0.966987
# [451]	eval-auc:0.964718	train-auc:0.967006
# [452]	eval-auc:0.964725	train-auc:0.967016
# [453]	eval-auc:0.964743	train-auc:0.967063
# [454]	eval-auc:0.964750	train-auc:0.967098
# [455]	eval-auc:0.964761	train-auc:0.967114
# [456]	eval-auc:0.964772	train-auc:0.967137
# [457]	eval-auc:0.964786	train-auc:0.967164
# [458]	eval-auc:0.964788	train-auc:0.967171
# [459]	eval-auc:0.964804	train-auc:0.967199
# [460]	eval-auc:0.964816	train-auc:0.967221
# [461]	eval-auc:0.964825	train-auc:0.967233
# [462]	eval-auc:0.964831	train-auc:0.967263
# [463]	eval-auc:0.964860	train-auc:0.967309
# [464]	eval-auc:0.964882	train-auc:0.967337
# [465]	eval-auc:0.964895	train-auc:0.967362
# [466]	eval-auc:0.964896	train-auc:0.967373
# [467]	eval-auc:0.964906	train-auc:0.967402
# [468]	eval-auc:0.964914	train-auc:0.967414
# [469]	eval-auc:0.964931	train-auc:0.967438
# [470]	eval-auc:0.964942	train-auc:0.967453
# [471]	eval-auc:0.964973	train-auc:0.967493
# [472]	eval-auc:0.964976	train-auc:0.967505
# [473]	eval-auc:0.964979	train-auc:0.967520
# [474]	eval-auc:0.964987	train-auc:0.967543
# [475]	eval-auc:0.964989	train-auc:0.967561
# [476]	eval-auc:0.964985	train-auc:0.967596
# [477]	eval-auc:0.965000	train-auc:0.967622
# [478]	eval-auc:0.965018	train-auc:0.967646
# [479]	eval-auc:0.965023	train-auc:0.967670
# [480]	eval-auc:0.965035	train-auc:0.967700
# [481]	eval-auc:0.965067	train-auc:0.967734
# [482]	eval-auc:0.965077	train-auc:0.967751
# [483]	eval-auc:0.965085	train-auc:0.967775
# [484]	eval-auc:0.965090	train-auc:0.967791
# [485]	eval-auc:0.965103	train-auc:0.967817
# [486]	eval-auc:0.965106	train-auc:0.967819
# [487]	eval-auc:0.965115	train-auc:0.967837
# [488]	eval-auc:0.965120	train-auc:0.967848
# [489]	eval-auc:0.965131	train-auc:0.967872
# [490]	eval-auc:0.965136	train-auc:0.967892
# [491]	eval-auc:0.965156	train-auc:0.967916
# [492]	eval-auc:0.965168	train-auc:0.967942
# [493]	eval-auc:0.965178	train-auc:0.967960
# [494]	eval-auc:0.965198	train-auc:0.967995
# [495]	eval-auc:0.965206	train-auc:0.968016
# [496]	eval-auc:0.965210	train-auc:0.968035
# [497]	eval-auc:0.965214	train-auc:0.968064
# [498]	eval-auc:0.965217	train-auc:0.968080
# [499]	eval-auc:0.965215	train-auc:0.968098
# [500]	eval-auc:0.965219	train-auc:0.968123
# [501]	eval-auc:0.965219	train-auc:0.968148
# [502]	eval-auc:0.965235	train-auc:0.968177
# [503]	eval-auc:0.965238	train-auc:0.968203
# [504]	eval-auc:0.965273	train-auc:0.968250
# [505]	eval-auc:0.965287	train-auc:0.968276
# [506]	eval-auc:0.965301	train-auc:0.968308
# [507]	eval-auc:0.965301	train-auc:0.968321
# [508]	eval-auc:0.965309	train-auc:0.968339
# [509]	eval-auc:0.965314	train-auc:0.968361
# [510]	eval-auc:0.965324	train-auc:0.968389
# [511]	eval-auc:0.965330	train-auc:0.968407
# [512]	eval-auc:0.965342	train-auc:0.968425
# [513]	eval-auc:0.965355	train-auc:0.968449
# [514]	eval-auc:0.965360	train-auc:0.968471
# [515]	eval-auc:0.965374	train-auc:0.968501
# [516]	eval-auc:0.965386	train-auc:0.968512
# [517]	eval-auc:0.965391	train-auc:0.968522
# [518]	eval-auc:0.965395	train-auc:0.968545
# [519]	eval-auc:0.965393	train-auc:0.968553
# [520]	eval-auc:0.965412	train-auc:0.968583
# [521]	eval-auc:0.965427	train-auc:0.968613
# [522]	eval-auc:0.965439	train-auc:0.968643
# [523]	eval-auc:0.965464	train-auc:0.968673
# [524]	eval-auc:0.965466	train-auc:0.968698
# [525]	eval-auc:0.965471	train-auc:0.968723
# [526]	eval-auc:0.965471	train-auc:0.968741
# [527]	eval-auc:0.965477	train-auc:0.968761
# [528]	eval-auc:0.965481	train-auc:0.968770
# [529]	eval-auc:0.965495	train-auc:0.968798
# [530]	eval-auc:0.965508	train-auc:0.968821
# [531]	eval-auc:0.965510	train-auc:0.968841
# [532]	eval-auc:0.965508	train-auc:0.968847
# [533]	eval-auc:0.965518	train-auc:0.968866
# [534]	eval-auc:0.965533	train-auc:0.968888
# [535]	eval-auc:0.965540	train-auc:0.968908
# [536]	eval-auc:0.965567	train-auc:0.968937
# [537]	eval-auc:0.965571	train-auc:0.968957
# [538]	eval-auc:0.965586	train-auc:0.968995
# [539]	eval-auc:0.965589	train-auc:0.969014
# [540]	eval-auc:0.965595	train-auc:0.969032
# [541]	eval-auc:0.965609	train-auc:0.969061
# [542]	eval-auc:0.965617	train-auc:0.969089
# [543]	eval-auc:0.965623	train-auc:0.969112
# [544]	eval-auc:0.965634	train-auc:0.969145
# [545]	eval-auc:0.965637	train-auc:0.969167
# [546]	eval-auc:0.965644	train-auc:0.969185
# [547]	eval-auc:0.965643	train-auc:0.969205
# [548]	eval-auc:0.965652	train-auc:0.969225
# [549]	eval-auc:0.965652	train-auc:0.969240
# [550]	eval-auc:0.965659	train-auc:0.969261
# [551]	eval-auc:0.965669	train-auc:0.969283
# [552]	eval-auc:0.965670	train-auc:0.969297
# [553]	eval-auc:0.965670	train-auc:0.969319
# [554]	eval-auc:0.965696	train-auc:0.969347
# [555]	eval-auc:0.965702	train-auc:0.969355
# [556]	eval-auc:0.965713	train-auc:0.969364
# [557]	eval-auc:0.965719	train-auc:0.969391
# [558]	eval-auc:0.965723	train-auc:0.969397
# [559]	eval-auc:0.965722	train-auc:0.969409
# [560]	eval-auc:0.965728	train-auc:0.969437
# [561]	eval-auc:0.965736	train-auc:0.969462
# [562]	eval-auc:0.965746	train-auc:0.969490
# [563]	eval-auc:0.965754	train-auc:0.969508
# [564]	eval-auc:0.965755	train-auc:0.969518
# [565]	eval-auc:0.965762	train-auc:0.969536
# [566]	eval-auc:0.965762	train-auc:0.969554
# [567]	eval-auc:0.965777	train-auc:0.969576
# [568]	eval-auc:0.965805	train-auc:0.969600
# [569]	eval-auc:0.965810	train-auc:0.969630
# [570]	eval-auc:0.965810	train-auc:0.969633
# [571]	eval-auc:0.965814	train-auc:0.969656
# [572]	eval-auc:0.965814	train-auc:0.969675
# [573]	eval-auc:0.965820	train-auc:0.969687
# [574]	eval-auc:0.965835	train-auc:0.969713
# [575]	eval-auc:0.965837	train-auc:0.969727
# [576]	eval-auc:0.965838	train-auc:0.969743
# [577]	eval-auc:0.965855	train-auc:0.969792
# [578]	eval-auc:0.965860	train-auc:0.969803
# [579]	eval-auc:0.965862	train-auc:0.969828
# [580]	eval-auc:0.965861	train-auc:0.969845
# [581]	eval-auc:0.965861	train-auc:0.969859
# [582]	eval-auc:0.965869	train-auc:0.969885
# [583]	eval-auc:0.965868	train-auc:0.969888
# [584]	eval-auc:0.965872	train-auc:0.969901
# [585]	eval-auc:0.965870	train-auc:0.969926
# [586]	eval-auc:0.965878	train-auc:0.969940
# [587]	eval-auc:0.965882	train-auc:0.969959
# [588]	eval-auc:0.965883	train-auc:0.969975
# [589]	eval-auc:0.965886	train-auc:0.970003
# [590]	eval-auc:0.965894	train-auc:0.970022
# [591]	eval-auc:0.965907	train-auc:0.970043
# [592]	eval-auc:0.965918	train-auc:0.970065
# [593]	eval-auc:0.965930	train-auc:0.970087
# [594]	eval-auc:0.965935	train-auc:0.970100
# [595]	eval-auc:0.965948	train-auc:0.970116
# [596]	eval-auc:0.965950	train-auc:0.970137
# [597]	eval-auc:0.965958	train-auc:0.970153
# [598]	eval-auc:0.965972	train-auc:0.970174
# [599]	eval-auc:0.965980	train-auc:0.970197
# [600]	eval-auc:0.965989	train-auc:0.970224
# [601]	eval-auc:0.965995	train-auc:0.970245
# [602]	eval-auc:0.966007	train-auc:0.970267
# [603]	eval-auc:0.966016	train-auc:0.970280
# [604]	eval-auc:0.966023	train-auc:0.970311
# [605]	eval-auc:0.966038	train-auc:0.970334
# [606]	eval-auc:0.966040	train-auc:0.970346
# [607]	eval-auc:0.966047	train-auc:0.970358
# [608]	eval-auc:0.966054	train-auc:0.970382
# [609]	eval-auc:0.966064	train-auc:0.970408
# [610]	eval-auc:0.966076	train-auc:0.970434
# [611]	eval-auc:0.966084	train-auc:0.970453
# [612]	eval-auc:0.966107	train-auc:0.970477
# [613]	eval-auc:0.966111	train-auc:0.970484
# [614]	eval-auc:0.966128	train-auc:0.970507
# [615]	eval-auc:0.966139	train-auc:0.970528
# [616]	eval-auc:0.966147	train-auc:0.970548
# [617]	eval-auc:0.966150	train-auc:0.970565
# [618]	eval-auc:0.966171	train-auc:0.970598
# [619]	eval-auc:0.966176	train-auc:0.970620
# [620]	eval-auc:0.966176	train-auc:0.970631
# [621]	eval-auc:0.966180	train-auc:0.970638
# [622]	eval-auc:0.966193	train-auc:0.970656
# [623]	eval-auc:0.966201	train-auc:0.970681
# [624]	eval-auc:0.966205	train-auc:0.970696
# [625]	eval-auc:0.966222	train-auc:0.970715
# [626]	eval-auc:0.966224	train-auc:0.970729
# [627]	eval-auc:0.966230	train-auc:0.970748
# [628]	eval-auc:0.966233	train-auc:0.970767
# [629]	eval-auc:0.966234	train-auc:0.970779
# [630]	eval-auc:0.966236	train-auc:0.970797
# [631]	eval-auc:0.966237	train-auc:0.970800
# [632]	eval-auc:0.966243	train-auc:0.970813
# [633]	eval-auc:0.966242	train-auc:0.970827
# [634]	eval-auc:0.966245	train-auc:0.970840
# [635]	eval-auc:0.966249	train-auc:0.970857
# [636]	eval-auc:0.966259	train-auc:0.970879
# [637]	eval-auc:0.966259	train-auc:0.970891
# [638]	eval-auc:0.966262	train-auc:0.970906
# [639]	eval-auc:0.966266	train-auc:0.970918
# [640]	eval-auc:0.966272	train-auc:0.970934
# [641]	eval-auc:0.966294	train-auc:0.970963
# [642]	eval-auc:0.966324	train-auc:0.971012
# [643]	eval-auc:0.966332	train-auc:0.971047
# [644]	eval-auc:0.966345	train-auc:0.971062
# [645]	eval-auc:0.966345	train-auc:0.971073
# [646]	eval-auc:0.966346	train-auc:0.971082
# [647]	eval-auc:0.966364	train-auc:0.971120
# [648]	eval-auc:0.966366	train-auc:0.971138
# [649]	eval-auc:0.966367	train-auc:0.971161
# [650]	eval-auc:0.966370	train-auc:0.971166
# [651]	eval-auc:0.966385	train-auc:0.971187
# [652]	eval-auc:0.966395	train-auc:0.971205
# [653]	eval-auc:0.966392	train-auc:0.971224
# [654]	eval-auc:0.966399	train-auc:0.971236
# [655]	eval-auc:0.966403	train-auc:0.971256
# [656]	eval-auc:0.966402	train-auc:0.971276
# [657]	eval-auc:0.966403	train-auc:0.971295
# [658]	eval-auc:0.966400	train-auc:0.971313
# [659]	eval-auc:0.966409	train-auc:0.971333
# [660]	eval-auc:0.966415	train-auc:0.971367
# [661]	eval-auc:0.966419	train-auc:0.971377
# [662]	eval-auc:0.966424	train-auc:0.971391
# [663]	eval-auc:0.966438	train-auc:0.971409
# [664]	eval-auc:0.966440	train-auc:0.971425
# [665]	eval-auc:0.966447	train-auc:0.971441
# [666]	eval-auc:0.966448	train-auc:0.971462
# [667]	eval-auc:0.966448	train-auc:0.971469
# [668]	eval-auc:0.966456	train-auc:0.971481
# [669]	eval-auc:0.966451	train-auc:0.971491
# [670]	eval-auc:0.966457	train-auc:0.971512
# [671]	eval-auc:0.966470	train-auc:0.971544
# [672]	eval-auc:0.966473	train-auc:0.971567
# [673]	eval-auc:0.966480	train-auc:0.971590
# [674]	eval-auc:0.966484	train-auc:0.971609
# [675]	eval-auc:0.966486	train-auc:0.971627
# [676]	eval-auc:0.966485	train-auc:0.971653
# [677]	eval-auc:0.966488	train-auc:0.971676
# [678]	eval-auc:0.966484	train-auc:0.971700
# [679]	eval-auc:0.966495	train-auc:0.971722
# [680]	eval-auc:0.966496	train-auc:0.971740
# [681]	eval-auc:0.966495	train-auc:0.971751
# [682]	eval-auc:0.966502	train-auc:0.971767
# [683]	eval-auc:0.966504	train-auc:0.971777
# [684]	eval-auc:0.966507	train-auc:0.971796
# [685]	eval-auc:0.966512	train-auc:0.971817
# [686]	eval-auc:0.966512	train-auc:0.971836
# [687]	eval-auc:0.966516	train-auc:0.971853
# [688]	eval-auc:0.966534	train-auc:0.971885
# [689]	eval-auc:0.966543	train-auc:0.971898
# [690]	eval-auc:0.966546	train-auc:0.971914
# [691]	eval-auc:0.966550	train-auc:0.971940
# [692]	eval-auc:0.966546	train-auc:0.971955
# [693]	eval-auc:0.966547	train-auc:0.971977
# [694]	eval-auc:0.966552	train-auc:0.971990
# [695]	eval-auc:0.966552	train-auc:0.971998
# [696]	eval-auc:0.966552	train-auc:0.972017
# [697]	eval-auc:0.966556	train-auc:0.972037
# [698]	eval-auc:0.966561	train-auc:0.972062
# [699]	eval-auc:0.966559	train-auc:0.972076
# [700]	eval-auc:0.966562	train-auc:0.972095
# [701]	eval-auc:0.966560	train-auc:0.972103
# [702]	eval-auc:0.966562	train-auc:0.972121
# [703]	eval-auc:0.966573	train-auc:0.972146
# [704]	eval-auc:0.966574	train-auc:0.972152
# [705]	eval-auc:0.966580	train-auc:0.972166
# [706]	eval-auc:0.966577	train-auc:0.972187
# [707]	eval-auc:0.966586	train-auc:0.972207
# [708]	eval-auc:0.966605	train-auc:0.972230
# [709]	eval-auc:0.966608	train-auc:0.972250
# [710]	eval-auc:0.966613	train-auc:0.972265
# [711]	eval-auc:0.966612	train-auc:0.972281
# [712]	eval-auc:0.966617	train-auc:0.972299
# [713]	eval-auc:0.966620	train-auc:0.972323
# [714]	eval-auc:0.966622	train-auc:0.972336
# [715]	eval-auc:0.966629	train-auc:0.972360
# [716]	eval-auc:0.966627	train-auc:0.972372
# [717]	eval-auc:0.966628	train-auc:0.972380
# [718]	eval-auc:0.966631	train-auc:0.972386
# [719]	eval-auc:0.966632	train-auc:0.972405
# [720]	eval-auc:0.966634	train-auc:0.972415
# [721]	eval-auc:0.966636	train-auc:0.972422
# [722]	eval-auc:0.966644	train-auc:0.972433
# [723]	eval-auc:0.966652	train-auc:0.972449
# [724]	eval-auc:0.966657	train-auc:0.972468
# [725]	eval-auc:0.966662	train-auc:0.972478
# [726]	eval-auc:0.966662	train-auc:0.972498
# [727]	eval-auc:0.966672	train-auc:0.972513
# [728]	eval-auc:0.966676	train-auc:0.972538
# [729]	eval-auc:0.966683	train-auc:0.972564
# [730]	eval-auc:0.966684	train-auc:0.972570
# [731]	eval-auc:0.966692	train-auc:0.972578
# [732]	eval-auc:0.966691	train-auc:0.972585
# [733]	eval-auc:0.966686	train-auc:0.972605
# [734]	eval-auc:0.966693	train-auc:0.972623
# [735]	eval-auc:0.966696	train-auc:0.972639
# [736]	eval-auc:0.966705	train-auc:0.972651
# [737]	eval-auc:0.966715	train-auc:0.972677
# [738]	eval-auc:0.966715	train-auc:0.972700
# [739]	eval-auc:0.966720	train-auc:0.972718
# [740]	eval-auc:0.966723	train-auc:0.972730
# [741]	eval-auc:0.966724	train-auc:0.972739
# [742]	eval-auc:0.966728	train-auc:0.972757
# [743]	eval-auc:0.966729	train-auc:0.972777
# [744]	eval-auc:0.966727	train-auc:0.972786
# [745]	eval-auc:0.966729	train-auc:0.972792
# [746]	eval-auc:0.966729	train-auc:0.972807
# [747]	eval-auc:0.966730	train-auc:0.972820
# [748]	eval-auc:0.966734	train-auc:0.972842
# [749]	eval-auc:0.966736	train-auc:0.972858
# [750]	eval-auc:0.966740	train-auc:0.972872
# [751]	eval-auc:0.966748	train-auc:0.972889
# [752]	eval-auc:0.966746	train-auc:0.972899
# [753]	eval-auc:0.966747	train-auc:0.972908
# [754]	eval-auc:0.966750	train-auc:0.972920
# [755]	eval-auc:0.966751	train-auc:0.972938
# [756]	eval-auc:0.966757	train-auc:0.972961
# [757]	eval-auc:0.966755	train-auc:0.972971
# [758]	eval-auc:0.966752	train-auc:0.972984
# [759]	eval-auc:0.966756	train-auc:0.973005
# [760]	eval-auc:0.966757	train-auc:0.973012
# [761]	eval-auc:0.966754	train-auc:0.973030
# [762]	eval-auc:0.966758	train-auc:0.973037
# [763]	eval-auc:0.966761	train-auc:0.973047
# [764]	eval-auc:0.966761	train-auc:0.973060
# [765]	eval-auc:0.966772	train-auc:0.973073
# [766]	eval-auc:0.966773	train-auc:0.973093
# [767]	eval-auc:0.966784	train-auc:0.973113
# [768]	eval-auc:0.966784	train-auc:0.973124
# [769]	eval-auc:0.966786	train-auc:0.973132
# [770]	eval-auc:0.966794	train-auc:0.973144
# [771]	eval-auc:0.966795	train-auc:0.973155
# [772]	eval-auc:0.966797	train-auc:0.973175
# [773]	eval-auc:0.966797	train-auc:0.973183
# [774]	eval-auc:0.966809	train-auc:0.973198
# [775]	eval-auc:0.966809	train-auc:0.973215
# [776]	eval-auc:0.966810	train-auc:0.973226
# [777]	eval-auc:0.966809	train-auc:0.973250
# [778]	eval-auc:0.966808	train-auc:0.973266
# [779]	eval-auc:0.966807	train-auc:0.973284
# [780]	eval-auc:0.966816	train-auc:0.973304
# [781]	eval-auc:0.966827	train-auc:0.973313
# [782]	eval-auc:0.966827	train-auc:0.973326
# [783]	eval-auc:0.966824	train-auc:0.973349
# [784]	eval-auc:0.966827	train-auc:0.973361
# [785]	eval-auc:0.966825	train-auc:0.973365
# [786]	eval-auc:0.966827	train-auc:0.973383
# [787]	eval-auc:0.966828	train-auc:0.973393
# [788]	eval-auc:0.966835	train-auc:0.973413
# [789]	eval-auc:0.966834	train-auc:0.973424
# [790]	eval-auc:0.966839	train-auc:0.973432
# [791]	eval-auc:0.966845	train-auc:0.973449
# [792]	eval-auc:0.966846	train-auc:0.973464
# [793]	eval-auc:0.966855	train-auc:0.973474
# [794]	eval-auc:0.966866	train-auc:0.973483
# [795]	eval-auc:0.966871	train-auc:0.973503
# [796]	eval-auc:0.966875	train-auc:0.973523
# [797]	eval-auc:0.966875	train-auc:0.973539
# [798]	eval-auc:0.966874	train-auc:0.973555
# [799]	eval-auc:0.966886	train-auc:0.973585
# [800]	eval-auc:0.966887	train-auc:0.973603
# [801]	eval-auc:0.966894	train-auc:0.973612
# [802]	eval-auc:0.966888	train-auc:0.973621
# [803]	eval-auc:0.966889	train-auc:0.973643
# [804]	eval-auc:0.966890	train-auc:0.973658
# [805]	eval-auc:0.966898	train-auc:0.973682
# [806]	eval-auc:0.966899	train-auc:0.973686
# [807]	eval-auc:0.966907	train-auc:0.973698
# [808]	eval-auc:0.966909	train-auc:0.973704
# [809]	eval-auc:0.966913	train-auc:0.973722
# [810]	eval-auc:0.966913	train-auc:0.973733
# [811]	eval-auc:0.966914	train-auc:0.973755
# [812]	eval-auc:0.966915	train-auc:0.973768
# [813]	eval-auc:0.966918	train-auc:0.973781
# [814]	eval-auc:0.966931	train-auc:0.973793
# [815]	eval-auc:0.966940	train-auc:0.973822
# [816]	eval-auc:0.966940	train-auc:0.973838
# [817]	eval-auc:0.966943	train-auc:0.973846
# [818]	eval-auc:0.966943	train-auc:0.973854
# [819]	eval-auc:0.966952	train-auc:0.973872
# [820]	eval-auc:0.966978	train-auc:0.973903
# [821]	eval-auc:0.966974	train-auc:0.973919
# [822]	eval-auc:0.966972	train-auc:0.973931
# [823]	eval-auc:0.966968	train-auc:0.973945
# [824]	eval-auc:0.966969	train-auc:0.973954
# [825]	eval-auc:0.966976	train-auc:0.973976
# [826]	eval-auc:0.966985	train-auc:0.973990
# [827]	eval-auc:0.966991	train-auc:0.974013
# [828]	eval-auc:0.966993	train-auc:0.974022
# [829]	eval-auc:0.966995	train-auc:0.974044
# [830]	eval-auc:0.966992	train-auc:0.974058
# [831]	eval-auc:0.966998	train-auc:0.974074
# [832]	eval-auc:0.967001	train-auc:0.974087
# [833]	eval-auc:0.967000	train-auc:0.974097
# [834]	eval-auc:0.967002	train-auc:0.974114
# [835]	eval-auc:0.967002	train-auc:0.974132
# [836]	eval-auc:0.967004	train-auc:0.974148
# [837]	eval-auc:0.967005	train-auc:0.974168
# [838]	eval-auc:0.967009	train-auc:0.974181
# [839]	eval-auc:0.967008	train-auc:0.974195
# [840]	eval-auc:0.967011	train-auc:0.974203
# [841]	eval-auc:0.967018	train-auc:0.974224
# [842]	eval-auc:0.967020	train-auc:0.974237
# [843]	eval-auc:0.967017	train-auc:0.974247
# [844]	eval-auc:0.967023	train-auc:0.974267
# [845]	eval-auc:0.967022	train-auc:0.974278
# [846]	eval-auc:0.967026	train-auc:0.974297
# [847]	eval-auc:0.967028	train-auc:0.974306
# [848]	eval-auc:0.967027	train-auc:0.974324
# [849]	eval-auc:0.967033	train-auc:0.974344
# [850]	eval-auc:0.967040	train-auc:0.974362
# [851]	eval-auc:0.967044	train-auc:0.974382
# [852]	eval-auc:0.967054	train-auc:0.974403
# [853]	eval-auc:0.967057	train-auc:0.974407
# [854]	eval-auc:0.967054	train-auc:0.974415
# [855]	eval-auc:0.967063	train-auc:0.974429
# [856]	eval-auc:0.967064	train-auc:0.974441
# [857]	eval-auc:0.967062	train-auc:0.974453
# [858]	eval-auc:0.967070	train-auc:0.974470
# [859]	eval-auc:0.967068	train-auc:0.974489
# [860]	eval-auc:0.967074	train-auc:0.974508
# [861]	eval-auc:0.967078	train-auc:0.974516
# [862]	eval-auc:0.967077	train-auc:0.974536
# [863]	eval-auc:0.967078	train-auc:0.974540
# [864]	eval-auc:0.967084	train-auc:0.974557
# [865]	eval-auc:0.967087	train-auc:0.974572
# [866]	eval-auc:0.967092	train-auc:0.974580
# [867]	eval-auc:0.967090	train-auc:0.974595
# [868]	eval-auc:0.967090	train-auc:0.974602
# [869]	eval-auc:0.967092	train-auc:0.974613
# [870]	eval-auc:0.967091	train-auc:0.974626
# [871]	eval-auc:0.967096	train-auc:0.974635
# [872]	eval-auc:0.967098	train-auc:0.974652
# [873]	eval-auc:0.967099	train-auc:0.974668
# [874]	eval-auc:0.967101	train-auc:0.974677
# [875]	eval-auc:0.967101	train-auc:0.974690
# [876]	eval-auc:0.967101	train-auc:0.974705
# [877]	eval-auc:0.967103	train-auc:0.974730
# [878]	eval-auc:0.967102	train-auc:0.974743
# [879]	eval-auc:0.967103	train-auc:0.974750
# [880]	eval-auc:0.967110	train-auc:0.974761
# [881]	eval-auc:0.967109	train-auc:0.974777
# [882]	eval-auc:0.967114	train-auc:0.974798
# [883]	eval-auc:0.967116	train-auc:0.974816
# [884]	eval-auc:0.967117	train-auc:0.974833
# [885]	eval-auc:0.967118	train-auc:0.974851
# [886]	eval-auc:0.967119	train-auc:0.974860
# [887]	eval-auc:0.967125	train-auc:0.974870
# [888]	eval-auc:0.967128	train-auc:0.974889
# [889]	eval-auc:0.967130	train-auc:0.974900
# [890]	eval-auc:0.967133	train-auc:0.974918
# [891]	eval-auc:0.967136	train-auc:0.974935
# [892]	eval-auc:0.967139	train-auc:0.974945
# [893]	eval-auc:0.967141	train-auc:0.974954
# [894]	eval-auc:0.967145	train-auc:0.974974
# [895]	eval-auc:0.967144	train-auc:0.974989
# [896]	eval-auc:0.967145	train-auc:0.975006
# [897]	eval-auc:0.967147	train-auc:0.975015
# [898]	eval-auc:0.967146	train-auc:0.975039
# [899]	eval-auc:0.967150	train-auc:0.975050
# [900]	eval-auc:0.967155	train-auc:0.975069
# [901]	eval-auc:0.967158	train-auc:0.975084
# [902]	eval-auc:0.967157	train-auc:0.975091
# [903]	eval-auc:0.967159	train-auc:0.975104
# [904]	eval-auc:0.967165	train-auc:0.975117
# [905]	eval-auc:0.967167	train-auc:0.975125
# [906]	eval-auc:0.967175	train-auc:0.975138
# [907]	eval-auc:0.967175	train-auc:0.975150
# [908]	eval-auc:0.967176	train-auc:0.975171
# [909]	eval-auc:0.967186	train-auc:0.975196
# [910]	eval-auc:0.967182	train-auc:0.975210
# [911]	eval-auc:0.967184	train-auc:0.975227
# [912]	eval-auc:0.967201	train-auc:0.975247
# [913]	eval-auc:0.967214	train-auc:0.975266
# [914]	eval-auc:0.967214	train-auc:0.975283
# [915]	eval-auc:0.967214	train-auc:0.975302
# [916]	eval-auc:0.967219	train-auc:0.975314
# [917]	eval-auc:0.967218	train-auc:0.975335
# [918]	eval-auc:0.967221	train-auc:0.975347
# [919]	eval-auc:0.967222	train-auc:0.975368
# [920]	eval-auc:0.967226	train-auc:0.975383
# [921]	eval-auc:0.967229	train-auc:0.975402
# [922]	eval-auc:0.967227	train-auc:0.975414
# [923]	eval-auc:0.967222	train-auc:0.975424
# [924]	eval-auc:0.967227	train-auc:0.975440
# [925]	eval-auc:0.967230	train-auc:0.975449
# [926]	eval-auc:0.967232	train-auc:0.975458
# [927]	eval-auc:0.967235	train-auc:0.975471
# [928]	eval-auc:0.967236	train-auc:0.975484
# [929]	eval-auc:0.967237	train-auc:0.975494
# [930]	eval-auc:0.967236	train-auc:0.975507
# [931]	eval-auc:0.967238	train-auc:0.975516
# [932]	eval-auc:0.967241	train-auc:0.975527
# [933]	eval-auc:0.967238	train-auc:0.975536
# [934]	eval-auc:0.967237	train-auc:0.975549
# [935]	eval-auc:0.967233	train-auc:0.975564
# [936]	eval-auc:0.967237	train-auc:0.975583
# [937]	eval-auc:0.967236	train-auc:0.975602
# [938]	eval-auc:0.967231	train-auc:0.975623
# [939]	eval-auc:0.967234	train-auc:0.975641
# [940]	eval-auc:0.967235	train-auc:0.975660
# [941]	eval-auc:0.967238	train-auc:0.975674
# [942]	eval-auc:0.967238	train-auc:0.975690
# [943]	eval-auc:0.967244	train-auc:0.975703
# [944]	eval-auc:0.967246	train-auc:0.975722
# [945]	eval-auc:0.967248	train-auc:0.975731
# [946]	eval-auc:0.967256	train-auc:0.975751
# [947]	eval-auc:0.967267	train-auc:0.975777
# [948]	eval-auc:0.967264	train-auc:0.975784
# [949]	eval-auc:0.967265	train-auc:0.975790
# [950]	eval-auc:0.967261	train-auc:0.975802
# [951]	eval-auc:0.967258	train-auc:0.975815
# [952]	eval-auc:0.967262	train-auc:0.975833
# [953]	eval-auc:0.967265	train-auc:0.975836
# [954]	eval-auc:0.967264	train-auc:0.975850
# [955]	eval-auc:0.967276	train-auc:0.975873
# [956]	eval-auc:0.967275	train-auc:0.975878
# [957]	eval-auc:0.967277	train-auc:0.975889
# [958]	eval-auc:0.967273	train-auc:0.975906
# [959]	eval-auc:0.967271	train-auc:0.975921
# [960]	eval-auc:0.967272	train-auc:0.975931
# [961]	eval-auc:0.967271	train-auc:0.975948
# [962]	eval-auc:0.967268	train-auc:0.975963
# [963]	eval-auc:0.967277	train-auc:0.975978
# [964]	eval-auc:0.967289	train-auc:0.975989
# [965]	eval-auc:0.967287	train-auc:0.976002
# [966]	eval-auc:0.967288	train-auc:0.976023
# [967]	eval-auc:0.967287	train-auc:0.976038
# [968]	eval-auc:0.967293	train-auc:0.976064
# [969]	eval-auc:0.967297	train-auc:0.976071
# [970]	eval-auc:0.967300	train-auc:0.976076
# [971]	eval-auc:0.967299	train-auc:0.976088
# [972]	eval-auc:0.967298	train-auc:0.976093
# [973]	eval-auc:0.967297	train-auc:0.976110
# [974]	eval-auc:0.967309	train-auc:0.976133
# [975]	eval-auc:0.967316	train-auc:0.976148
# [976]	eval-auc:0.967318	train-auc:0.976158
# [977]	eval-auc:0.967320	train-auc:0.976173
# [978]	eval-auc:0.967320	train-auc:0.976184
# [979]	eval-auc:0.967318	train-auc:0.976202
# [980]	eval-auc:0.967319	train-auc:0.976218
# [981]	eval-auc:0.967319	train-auc:0.976225
# [982]	eval-auc:0.967322	train-auc:0.976240
# [983]	eval-auc:0.967330	train-auc:0.976256
# [984]	eval-auc:0.967335	train-auc:0.976264
# [985]	eval-auc:0.967348	train-auc:0.976286
# [986]	eval-auc:0.967346	train-auc:0.976296
# [987]	eval-auc:0.967344	train-auc:0.976311
# [988]	eval-auc:0.967350	train-auc:0.976329
# [989]	eval-auc:0.967356	train-auc:0.976338
# [990]	eval-auc:0.967360	train-auc:0.976353
# [991]	eval-auc:0.967362	train-auc:0.976369
# [992]	eval-auc:0.967362	train-auc:0.976378
# [993]	eval-auc:0.967361	train-auc:0.976384
# [994]	eval-auc:0.967358	train-auc:0.976399
# [995]	eval-auc:0.967369	train-auc:0.976416
# [996]	eval-auc:0.967371	train-auc:0.976425
# [997]	eval-auc:0.967370	train-auc:0.976441
# [998]	eval-auc:0.967374	train-auc:0.976454
# Bag 2 of 50
# [999]	eval-auc:0.967381	train-auc:0.976473
# Will train until train error hasn't decreased in 100 rounds.
# [0]	eval-auc:0.921657	train-auc:0.917875
# [1]	eval-auc:0.933326	train-auc:0.931086
# [2]	eval-auc:0.938252	train-auc:0.935874
# [3]	eval-auc:0.942612	train-auc:0.940130
# [4]	eval-auc:0.942561	train-auc:0.940059
# [5]	eval-auc:0.943574	train-auc:0.941102
# [6]	eval-auc:0.945107	train-auc:0.942662
# [7]	eval-auc:0.946806	train-auc:0.944325
# [8]	eval-auc:0.946108	train-auc:0.943730
# [9]	eval-auc:0.945370	train-auc:0.943097
# [10]	eval-auc:0.945098	train-auc:0.942944
# [11]	eval-auc:0.944896	train-auc:0.942748
# [12]	eval-auc:0.945553	train-auc:0.943355
# [13]	eval-auc:0.945888	train-auc:0.943552
# [14]	eval-auc:0.945767	train-auc:0.943358
# [15]	eval-auc:0.946341	train-auc:0.943970
# [16]	eval-auc:0.946207	train-auc:0.943878
# [17]	eval-auc:0.946036	train-auc:0.943740
# [18]	eval-auc:0.946109	train-auc:0.943779
# [19]	eval-auc:0.946334	train-auc:0.943968
# [20]	eval-auc:0.946889	train-auc:0.944421
# [21]	eval-auc:0.947274	train-auc:0.944865
# [22]	eval-auc:0.947088	train-auc:0.944695
# [23]	eval-auc:0.946848	train-auc:0.944478
# [24]	eval-auc:0.946645	train-auc:0.944344
# [25]	eval-auc:0.947022	train-auc:0.944758
# [26]	eval-auc:0.947286	train-auc:0.944995
# [27]	eval-auc:0.947631	train-auc:0.945393
# [28]	eval-auc:0.948035	train-auc:0.945885
# [29]	eval-auc:0.947867	train-auc:0.945737
# [30]	eval-auc:0.947915	train-auc:0.945778
# [31]	eval-auc:0.948002	train-auc:0.945855
# [32]	eval-auc:0.948119	train-auc:0.945990
# [33]	eval-auc:0.948109	train-auc:0.945979
# [34]	eval-auc:0.948325	train-auc:0.946221
# [35]	eval-auc:0.948557	train-auc:0.946444
# [36]	eval-auc:0.948569	train-auc:0.946426
# [37]	eval-auc:0.948868	train-auc:0.946771
# [38]	eval-auc:0.948884	train-auc:0.946767
# [39]	eval-auc:0.948839	train-auc:0.946704
# [40]	eval-auc:0.948954	train-auc:0.946854
# [41]	eval-auc:0.948990	train-auc:0.946903
# [42]	eval-auc:0.949011	train-auc:0.946936
# [43]	eval-auc:0.949032	train-auc:0.946939
# [44]	eval-auc:0.949012	train-auc:0.946897
# [45]	eval-auc:0.948959	train-auc:0.946847
# [46]	eval-auc:0.949113	train-auc:0.947021
# [47]	eval-auc:0.949323	train-auc:0.947291
# [48]	eval-auc:0.949278	train-auc:0.947252
# [49]	eval-auc:0.949284	train-auc:0.947280
# [50]	eval-auc:0.949276	train-auc:0.947283
# [51]	eval-auc:0.949348	train-auc:0.947346
# [52]	eval-auc:0.949357	train-auc:0.947358
# [53]	eval-auc:0.949338	train-auc:0.947319
# [54]	eval-auc:0.949367	train-auc:0.947350
# [55]	eval-auc:0.949382	train-auc:0.947358
# [56]	eval-auc:0.949482	train-auc:0.947434
# [57]	eval-auc:0.949656	train-auc:0.947575
# [58]	eval-auc:0.949725	train-auc:0.947638
# [59]	eval-auc:0.949859	train-auc:0.947764
# [60]	eval-auc:0.949907	train-auc:0.947820
# [61]	eval-auc:0.949886	train-auc:0.947825
# [62]	eval-auc:0.950054	train-auc:0.948033
# [63]	eval-auc:0.950058	train-auc:0.948041
# [64]	eval-auc:0.950062	train-auc:0.948055
# [65]	eval-auc:0.950162	train-auc:0.948127
# [66]	eval-auc:0.950257	train-auc:0.948242
# [67]	eval-auc:0.950405	train-auc:0.948443
# [68]	eval-auc:0.950438	train-auc:0.948480
# [69]	eval-auc:0.950451	train-auc:0.948500
# [70]	eval-auc:0.950647	train-auc:0.948707
# [71]	eval-auc:0.950649	train-auc:0.948718
# [72]	eval-auc:0.950635	train-auc:0.948699
# [73]	eval-auc:0.950766	train-auc:0.948851
# [74]	eval-auc:0.950854	train-auc:0.948940
# [75]	eval-auc:0.950954	train-auc:0.949050
# [76]	eval-auc:0.951026	train-auc:0.949108
# [77]	eval-auc:0.951207	train-auc:0.949270
# [78]	eval-auc:0.951155	train-auc:0.949225
# [79]	eval-auc:0.951232	train-auc:0.949302
# [80]	eval-auc:0.951389	train-auc:0.949446
# [81]	eval-auc:0.951502	train-auc:0.949601
# [82]	eval-auc:0.951633	train-auc:0.949699
# [83]	eval-auc:0.951761	train-auc:0.949835
# [84]	eval-auc:0.951874	train-auc:0.949952
# [85]	eval-auc:0.951965	train-auc:0.950055
# [86]	eval-auc:0.952058	train-auc:0.950140
# [87]	eval-auc:0.952105	train-auc:0.950183
# [88]	eval-auc:0.952128	train-auc:0.950226
# [89]	eval-auc:0.952206	train-auc:0.950321
# [90]	eval-auc:0.952197	train-auc:0.950338
# [91]	eval-auc:0.952312	train-auc:0.950460
# [92]	eval-auc:0.952345	train-auc:0.950492
# [93]	eval-auc:0.952401	train-auc:0.950567
# [94]	eval-auc:0.952479	train-auc:0.950651
# [95]	eval-auc:0.952461	train-auc:0.950657
# [96]	eval-auc:0.952754	train-auc:0.950982
# [97]	eval-auc:0.952798	train-auc:0.951028
# [98]	eval-auc:0.952815	train-auc:0.951039
# [99]	eval-auc:0.952882	train-auc:0.951127
# [100]	eval-auc:0.952962	train-auc:0.951230
# [101]	eval-auc:0.953168	train-auc:0.951439
# [102]	eval-auc:0.953161	train-auc:0.951440
# [103]	eval-auc:0.953189	train-auc:0.951475
# [104]	eval-auc:0.953354	train-auc:0.951633
# [105]	eval-auc:0.953587	train-auc:0.951899
# [106]	eval-auc:0.953795	train-auc:0.952116
# [107]	eval-auc:0.953860	train-auc:0.952183
# [108]	eval-auc:0.953848	train-auc:0.952182
# [109]	eval-auc:0.954051	train-auc:0.952419
# [110]	eval-auc:0.954069	train-auc:0.952441
# [111]	eval-auc:0.954246	train-auc:0.952648
# [112]	eval-auc:0.954356	train-auc:0.952774
# [113]	eval-auc:0.954349	train-auc:0.952776
# [114]	eval-auc:0.954347	train-auc:0.952782
# [115]	eval-auc:0.954376	train-auc:0.952821
# [116]	eval-auc:0.954440	train-auc:0.952918
# [117]	eval-auc:0.954532	train-auc:0.953019
# ...
# [667]	eval-auc:0.966474	train-auc:0.971817
# [668]	eval-auc:0.966479	train-auc:0.971827
# [669]	eval-auc:0.966482	train-auc:0.971838
# [670]	eval-auc:0.966492	train-auc:0.971862
# [671]	eval-auc:0.966505	train-auc:0.971892
# [672]	eval-auc:0.966517	train-auc:0.971906
# [673]	eval-auc:0.966513	train-auc:0.971926
# [674]	eval-auc:0.966536	train-auc:0.971955
# [675]	eval-auc:0.966538	train-auc:0.971962
# [676]	eval-auc:0.966550	train-auc:0.971986
# [677]	eval-auc:0.966562	train-auc:0.972004
# [678]	eval-auc:0.966560	train-auc:0.972024
# [679]	eval-auc:0.966565	train-auc:0.972040
# [680]	eval-auc:0.966571	train-auc:0.972061
# [681]	eval-auc:0.966568	train-auc:0.972077
# [682]	eval-auc:0.966564	train-auc:0.972092
# [683]	eval-auc:0.966569	train-auc:0.972113
# [684]	eval-auc:0.966572	train-auc:0.972127
# [685]	eval-auc:0.966569	train-auc:0.972132
# [686]	eval-auc:0.966566	train-auc:0.972135
# [687]	eval-auc:0.966576	train-auc:0.972152
# [688]	eval-auc:0.966575	train-auc:0.972171
# [689]	eval-auc:0.966579	train-auc:0.972194
# [690]	eval-auc:0.966579	train-auc:0.972216
# [691]	eval-auc:0.966577	train-auc:0.972222
# [692]	eval-auc:0.966581	train-auc:0.972237
# [693]	eval-auc:0.966578	train-auc:0.972259
# [694]	eval-auc:0.966580	train-auc:0.972271
# [695]	eval-auc:0.966584	train-auc:0.972275
# [696]	eval-auc:0.966581	train-auc:0.972290
# [697]	eval-auc:0.966587	train-auc:0.972304
# [698]	eval-auc:0.966590	train-auc:0.972319
# [699]	eval-auc:0.966600	train-auc:0.972336
# [700]	eval-auc:0.966601	train-auc:0.972354
# [701]	eval-auc:0.966604	train-auc:0.972370
# [702]	eval-auc:0.966623	train-auc:0.972395
# [703]	eval-auc:0.966623	train-auc:0.972406
# [704]	eval-auc:0.966627	train-auc:0.972424
# [705]	eval-auc:0.966633	train-auc:0.972431
# [706]	eval-auc:0.966635	train-auc:0.972440
# [707]	eval-auc:0.966642	train-auc:0.972458
# [708]	eval-auc:0.966644	train-auc:0.972477
# [709]	eval-auc:0.966646	train-auc:0.972484
# [710]	eval-auc:0.966651	train-auc:0.972506
# [711]	eval-auc:0.966655	train-auc:0.972536
# [712]	eval-auc:0.966663	train-auc:0.972558
# [713]	eval-auc:0.966673	train-auc:0.972572
# [714]	eval-auc:0.966674	train-auc:0.972593
# [715]	eval-auc:0.966676	train-auc:0.972610
# [716]	eval-auc:0.966680	train-auc:0.972623
# [717]	eval-auc:0.966679	train-auc:0.972629
# [718]	eval-auc:0.966682	train-auc:0.972633
# [719]	eval-auc:0.966683	train-auc:0.972649
# [720]	eval-auc:0.966687	train-auc:0.972668
# [721]	eval-auc:0.966690	train-auc:0.972689
# [722]	eval-auc:0.966698	train-auc:0.972707
# [723]	eval-auc:0.966696	train-auc:0.972718
# [724]	eval-auc:0.966697	train-auc:0.972743
# [725]	eval-auc:0.966696	train-auc:0.972759
# [726]	eval-auc:0.966704	train-auc:0.972776
# [727]	eval-auc:0.966707	train-auc:0.972792
# [728]	eval-auc:0.966712	train-auc:0.972806
# [729]	eval-auc:0.966725	train-auc:0.972844
# [730]	eval-auc:0.966731	train-auc:0.972872
# [731]	eval-auc:0.966732	train-auc:0.972892
# [732]	eval-auc:0.966738	train-auc:0.972912
# [733]	eval-auc:0.966740	train-auc:0.972927
# [734]	eval-auc:0.966741	train-auc:0.972947
# [735]	eval-auc:0.966739	train-auc:0.972968
# [736]	eval-auc:0.966743	train-auc:0.972985
# [737]	eval-auc:0.966747	train-auc:0.973002
# [738]	eval-auc:0.966754	train-auc:0.973023
# [739]	eval-auc:0.966759	train-auc:0.973044
# [740]	eval-auc:0.966763	train-auc:0.973063
# [741]	eval-auc:0.966765	train-auc:0.973075
# [742]	eval-auc:0.966767	train-auc:0.973081
# [743]	eval-auc:0.966771	train-auc:0.973105
# [744]	eval-auc:0.966793	train-auc:0.973127
# [745]	eval-auc:0.966808	train-auc:0.973145
# [746]	eval-auc:0.966815	train-auc:0.973157
# [747]	eval-auc:0.966825	train-auc:0.973175
# [748]	eval-auc:0.966831	train-auc:0.973183
# [749]	eval-auc:0.966838	train-auc:0.973196
# [750]	eval-auc:0.966840	train-auc:0.973211
# [751]	eval-auc:0.966842	train-auc:0.973218
# [752]	eval-auc:0.966844	train-auc:0.973228
# [753]	eval-auc:0.966845	train-auc:0.973238
# [754]	eval-auc:0.966848	train-auc:0.973251
# [755]	eval-auc:0.966848	train-auc:0.973273
# [756]	eval-auc:0.966852	train-auc:0.973298
# [757]	eval-auc:0.966850	train-auc:0.973313
# [758]	eval-auc:0.966862	train-auc:0.973330
# [759]	eval-auc:0.966863	train-auc:0.973344
# [760]	eval-auc:0.966864	train-auc:0.973355
# [761]	eval-auc:0.966870	train-auc:0.973369
# [762]	eval-auc:0.966876	train-auc:0.973397
# [763]	eval-auc:0.966878	train-auc:0.973423
# [764]	eval-auc:0.966880	train-auc:0.973439
# [765]	eval-auc:0.966884	train-auc:0.973458
# [766]	eval-auc:0.966888	train-auc:0.973481
# [767]	eval-auc:0.966888	train-auc:0.973488
# [768]	eval-auc:0.966896	train-auc:0.973506
# [769]	eval-auc:0.966903	train-auc:0.973520
# [770]	eval-auc:0.966906	train-auc:0.973530
# [771]	eval-auc:0.966909	train-auc:0.973539
# [772]	eval-auc:0.966912	train-auc:0.973554
# [773]	eval-auc:0.966923	train-auc:0.973571
# [774]	eval-auc:0.966934	train-auc:0.973583
# [775]	eval-auc:0.966937	train-auc:0.973605
# [776]	eval-auc:0.966941	train-auc:0.973617
# [777]	eval-auc:0.966942	train-auc:0.973631
# [778]	eval-auc:0.966955	train-auc:0.973671
# [779]	eval-auc:0.966954	train-auc:0.973688
# [780]	eval-auc:0.966955	train-auc:0.973699
# [781]	eval-auc:0.966953	train-auc:0.973706
# [782]	eval-auc:0.966954	train-auc:0.973719
# [783]	eval-auc:0.966959	train-auc:0.973734
# [784]	eval-auc:0.966959	train-auc:0.973752
# [785]	eval-auc:0.966963	train-auc:0.973764
# [786]	eval-auc:0.966960	train-auc:0.973781
# [787]	eval-auc:0.966961	train-auc:0.973789
# [788]	eval-auc:0.966970	train-auc:0.973807
# [789]	eval-auc:0.966972	train-auc:0.973812
# [790]	eval-auc:0.966975	train-auc:0.973827
# [791]	eval-auc:0.966973	train-auc:0.973836
# [792]	eval-auc:0.966975	train-auc:0.973842
# [793]	eval-auc:0.966985	train-auc:0.973859
# [794]	eval-auc:0.966987	train-auc:0.973871
# [795]	eval-auc:0.966986	train-auc:0.973884
# [796]	eval-auc:0.966990	train-auc:0.973901
# [797]	eval-auc:0.966999	train-auc:0.973930
# [798]	eval-auc:0.966999	train-auc:0.973937
# [799]	eval-auc:0.967012	train-auc:0.973953
# [800]	eval-auc:0.967023	train-auc:0.973981
# [801]	eval-auc:0.967021	train-auc:0.973995
# [802]	eval-auc:0.967026	train-auc:0.974016
# [803]	eval-auc:0.967032	train-auc:0.974034
# [804]	eval-auc:0.967042	train-auc:0.974047
# [805]	eval-auc:0.967043	train-auc:0.974067
# [806]	eval-auc:0.967040	train-auc:0.974087
# [807]	eval-auc:0.967038	train-auc:0.974093
# [808]	eval-auc:0.967040	train-auc:0.974104
# [809]	eval-auc:0.967050	train-auc:0.974121
# [810]	eval-auc:0.967062	train-auc:0.974144
# [811]	eval-auc:0.967075	train-auc:0.974155
# [812]	eval-auc:0.967076	train-auc:0.974175
# [813]	eval-auc:0.967078	train-auc:0.974180
# [814]	eval-auc:0.967092	train-auc:0.974202
# [815]	eval-auc:0.967094	train-auc:0.974217
# [816]	eval-auc:0.967088	train-auc:0.974236
# [817]	eval-auc:0.967090	train-auc:0.974254
# [818]	eval-auc:0.967092	train-auc:0.974260
# [819]	eval-auc:0.967096	train-auc:0.974274
# [820]	eval-auc:0.967105	train-auc:0.974296
# [821]	eval-auc:0.967106	train-auc:0.974314
# [822]	eval-auc:0.967103	train-auc:0.974329
# [823]	eval-auc:0.967104	train-auc:0.974339
# [824]	eval-auc:0.967104	train-auc:0.974359
# [825]	eval-auc:0.967106	train-auc:0.974384
# [826]	eval-auc:0.967104	train-auc:0.974405
# [827]	eval-auc:0.967104	train-auc:0.974412
# [828]	eval-auc:0.967107	train-auc:0.974432
# [829]	eval-auc:0.967109	train-auc:0.974444
# [830]	eval-auc:0.967111	train-auc:0.974464
# [831]	eval-auc:0.967120	train-auc:0.974489
# [832]	eval-auc:0.967140	train-auc:0.974513
# [833]	eval-auc:0.967143	train-auc:0.974533
# [834]	eval-auc:0.967149	train-auc:0.974546
# [835]	eval-auc:0.967157	train-auc:0.974568
# [836]	eval-auc:0.967162	train-auc:0.974587
# [837]	eval-auc:0.967159	train-auc:0.974596
# [838]	eval-auc:0.967161	train-auc:0.974603
# [839]	eval-auc:0.967167	train-auc:0.974625
# [840]	eval-auc:0.967174	train-auc:0.974641
# [841]	eval-auc:0.967176	train-auc:0.974652
# [842]	eval-auc:0.967175	train-auc:0.974657
# [843]	eval-auc:0.967182	train-auc:0.974671
# [844]	eval-auc:0.967181	train-auc:0.974681
# [845]	eval-auc:0.967189	train-auc:0.974690
# [846]	eval-auc:0.967188	train-auc:0.974711
# [847]	eval-auc:0.967195	train-auc:0.974724
# [848]	eval-auc:0.967194	train-auc:0.974738
# [849]	eval-auc:0.967207	train-auc:0.974758
# [850]	eval-auc:0.967216	train-auc:0.974776
# [851]	eval-auc:0.967215	train-auc:0.974790
# [852]	eval-auc:0.967214	train-auc:0.974804
# [853]	eval-auc:0.967215	train-auc:0.974817
# [854]	eval-auc:0.967220	train-auc:0.974837
# [855]	eval-auc:0.967219	train-auc:0.974853
# [856]	eval-auc:0.967219	train-auc:0.974872
# [857]	eval-auc:0.967221	train-auc:0.974884
# [858]	eval-auc:0.967218	train-auc:0.974891
# [859]	eval-auc:0.967227	train-auc:0.974911
# [860]	eval-auc:0.967239	train-auc:0.974928
# [861]	eval-auc:0.967238	train-auc:0.974944
# [862]	eval-auc:0.967244	train-auc:0.974973
# [863]	eval-auc:0.967248	train-auc:0.974992
# [864]	eval-auc:0.967247	train-auc:0.975007
# [865]	eval-auc:0.967247	train-auc:0.975021
# [866]	eval-auc:0.967246	train-auc:0.975037
# [867]	eval-auc:0.967246	train-auc:0.975050
# [868]	eval-auc:0.967248	train-auc:0.975065
# [869]	eval-auc:0.967253	train-auc:0.975072
# [870]	eval-auc:0.967250	train-auc:0.975079
# [871]	eval-auc:0.967247	train-auc:0.975083
# [872]	eval-auc:0.967247	train-auc:0.975089
# [873]	eval-auc:0.967249	train-auc:0.975093
# [874]	eval-auc:0.967252	train-auc:0.975110
# [875]	eval-auc:0.967250	train-auc:0.975125
# [876]	eval-auc:0.967255	train-auc:0.975132
# [877]	eval-auc:0.967270	train-auc:0.975145
# [878]	eval-auc:0.967276	train-auc:0.975157
# [879]	eval-auc:0.967276	train-auc:0.975172
# [880]	eval-auc:0.967271	train-auc:0.975186
# [881]	eval-auc:0.967283	train-auc:0.975198
# [882]	eval-auc:0.967284	train-auc:0.975209
# [883]	eval-auc:0.967290	train-auc:0.975230
# [884]	eval-auc:0.967292	train-auc:0.975248
# [885]	eval-auc:0.967294	train-auc:0.975267
# [886]	eval-auc:0.967298	train-auc:0.975279
# [887]	eval-auc:0.967302	train-auc:0.975287
# [888]	eval-auc:0.967302	train-auc:0.975305
# [889]	eval-auc:0.967318	train-auc:0.975325
# [890]	eval-auc:0.967318	train-auc:0.975329
# [891]	eval-auc:0.967316	train-auc:0.975335
# [892]	eval-auc:0.967316	train-auc:0.975349
# [893]	eval-auc:0.967320	train-auc:0.975365
# [894]	eval-auc:0.967331	train-auc:0.975386
# [895]	eval-auc:0.967341	train-auc:0.975408
# [896]	eval-auc:0.967341	train-auc:0.975426
# [897]	eval-auc:0.967349	train-auc:0.975442
# [898]	eval-auc:0.967352	train-auc:0.975454
# [899]	eval-auc:0.967367	train-auc:0.975481
# [900]	eval-auc:0.967368	train-auc:0.975495
# [901]	eval-auc:0.967375	train-auc:0.975515
# [902]	eval-auc:0.967377	train-auc:0.975525
# [903]	eval-auc:0.967374	train-auc:0.975534
# [904]	eval-auc:0.967377	train-auc:0.975547
# [905]	eval-auc:0.967377	train-auc:0.975569
# [906]	eval-auc:0.967377	train-auc:0.975574
# [907]	eval-auc:0.967378	train-auc:0.975589
# [908]	eval-auc:0.967384	train-auc:0.975599
# [909]	eval-auc:0.967386	train-auc:0.975619
# [910]	eval-auc:0.967391	train-auc:0.975635
# [911]	eval-auc:0.967396	train-auc:0.975654
# [912]	eval-auc:0.967399	train-auc:0.975665
# [913]	eval-auc:0.967399	train-auc:0.975675
# [914]	eval-auc:0.967401	train-auc:0.975688
# [915]	eval-auc:0.967401	train-auc:0.975699
# [916]	eval-auc:0.967396	train-auc:0.975717
# [917]	eval-auc:0.967397	train-auc:0.975729
# [918]	eval-auc:0.967397	train-auc:0.975731
# [919]	eval-auc:0.967395	train-auc:0.975740
# [920]	eval-auc:0.967398	train-auc:0.975754
# [921]	eval-auc:0.967414	train-auc:0.975779
# [922]	eval-auc:0.967412	train-auc:0.975796
# [923]	eval-auc:0.967409	train-auc:0.975814
# [924]	eval-auc:0.967412	train-auc:0.975830
# [925]	eval-auc:0.967415	train-auc:0.975843
# [926]	eval-auc:0.967413	train-auc:0.975856
# [927]	eval-auc:0.967416	train-auc:0.975873
# [928]	eval-auc:0.967419	train-auc:0.975879
# [929]	eval-auc:0.967416	train-auc:0.975887
# [930]	eval-auc:0.967415	train-auc:0.975891
# [931]	eval-auc:0.967415	train-auc:0.975904
# [932]	eval-auc:0.967418	train-auc:0.975917
# [933]	eval-auc:0.967418	train-auc:0.975929
# [934]	eval-auc:0.967417	train-auc:0.975935
# [935]	eval-auc:0.967415	train-auc:0.975938
# [936]	eval-auc:0.967419	train-auc:0.975950
# [937]	eval-auc:0.967421	train-auc:0.975958
# [938]	eval-auc:0.967418	train-auc:0.975974
# [939]	eval-auc:0.967420	train-auc:0.975987
# [940]	eval-auc:0.967417	train-auc:0.976006
# [941]	eval-auc:0.967421	train-auc:0.976022
# [942]	eval-auc:0.967421	train-auc:0.976035
# [943]	eval-auc:0.967420	train-auc:0.976047
# [944]	eval-auc:0.967419	train-auc:0.976056
# [945]	eval-auc:0.967418	train-auc:0.976067
# [946]	eval-auc:0.967421	train-auc:0.976079
# [947]	eval-auc:0.967424	train-auc:0.976087
# [948]	eval-auc:0.967430	train-auc:0.976096
# [949]	eval-auc:0.967439	train-auc:0.976106
# [950]	eval-auc:0.967439	train-auc:0.976125
# [951]	eval-auc:0.967443	train-auc:0.976135
# [952]	eval-auc:0.967444	train-auc:0.976147
# [953]	eval-auc:0.967441	train-auc:0.976158
# [954]	eval-auc:0.967437	train-auc:0.976169
# [955]	eval-auc:0.967442	train-auc:0.976180
# [956]	eval-auc:0.967439	train-auc:0.976183
# [957]	eval-auc:0.967437	train-auc:0.976195
# [958]	eval-auc:0.967435	train-auc:0.976199
# [959]	eval-auc:0.967436	train-auc:0.976202
# [960]	eval-auc:0.967442	train-auc:0.976220
# [961]	eval-auc:0.967443	train-auc:0.976232
# [962]	eval-auc:0.967444	train-auc:0.976247
# [963]	eval-auc:0.967445	train-auc:0.976253
# [964]	eval-auc:0.967448	train-auc:0.976265
# [965]	eval-auc:0.967449	train-auc:0.976284
# [966]	eval-auc:0.967453	train-auc:0.976299
# [967]	eval-auc:0.967451	train-auc:0.976315
# [968]	eval-auc:0.967450	train-auc:0.976327
# [969]	eval-auc:0.967452	train-auc:0.976336
# [970]	eval-auc:0.967458	train-auc:0.976347
# [971]	eval-auc:0.967458	train-auc:0.976360
# [972]	eval-auc:0.967464	train-auc:0.976369
# [973]	eval-auc:0.967466	train-auc:0.976375
# [974]	eval-auc:0.967466	train-auc:0.976388
# [975]	eval-auc:0.967465	train-auc:0.976397
# [976]	eval-auc:0.967467	train-auc:0.976417
# [977]	eval-auc:0.967465	train-auc:0.976430
# [978]	eval-auc:0.967471	train-auc:0.976442
# [979]	eval-auc:0.967470	train-auc:0.976454
# [980]	eval-auc:0.967478	train-auc:0.976474
# [981]	eval-auc:0.967481	train-auc:0.976484
# [982]	eval-auc:0.967483	train-auc:0.976505
# [983]	eval-auc:0.967492	train-auc:0.976520
# [984]	eval-auc:0.967495	train-auc:0.976531
# [985]	eval-auc:0.967494	train-auc:0.976540
# [986]	eval-auc:0.967492	train-auc:0.976556
# [987]	eval-auc:0.967487	train-auc:0.976571
# [988]	eval-auc:0.967486	train-auc:0.976581
# [989]	eval-auc:0.967486	train-auc:0.976594
# [990]	eval-auc:0.967492	train-auc:0.976609
# [991]	eval-auc:0.967494	train-auc:0.976625
# [992]	eval-auc:0.967492	train-auc:0.976633
# [993]	eval-auc:0.967494	train-auc:0.976654
# [994]	eval-auc:0.967493	train-auc:0.976662
# [995]	eval-auc:0.967497	train-auc:0.976675
# [996]	eval-auc:0.967499	train-auc:0.976690
# [997]	eval-auc:0.967504	train-auc:0.976695
# [998]	eval-auc:0.967508	train-auc:0.976708
# Bag 14 of 50
# [999]	eval-auc:0.967511	train-auc:0.976718
# Will train until train error hasn't decreased in 100 rounds.
# [0]	eval-auc:0.929023	train-auc:0.925561
# [1]	eval-auc:0.929106	train-auc:0.925733
# [2]	eval-auc:0.937082	train-auc:0.934610
# [3]	eval-auc:0.938382	train-auc:0.936245
# [4]	eval-auc:0.939616	train-auc:0.937236
# [5]	eval-auc:0.939507	train-auc:0.937448
# [6]	eval-auc:0.938996	train-auc:0.936682
# [7]	eval-auc:0.939403	train-auc:0.936956
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-24ca2ac0684c> in <module>()
#      30     watchlist = [(xg_test,'eval'), (xg_train,'train')]
#      31     model = xgb.train(param, xg_train, num_round, watchlist,
# ---> 32                       early_stopping_rounds=100)
#      33     model.save_model('bag_models/model{}'.format(i+49))
#      34     models.append(model)
#
# /usr/lib/python3.5/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, learning_rates, xgb_model)
#     196                 else:
#     197                     bst.set_param({'eta': learning_rates(i, num_boost_round)})
# --> 198             bst.update(dtrain, i, obj)
#     199             nboost += 1
#     200             bst_eval_set = bst.eval_set(evals, i, feval)
#
# /usr/lib/python3.5/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#     692
#     693         if fobj is None:
# --> 694             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, iteration, dtrain.handle))
#     695         else:
#     696             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %% [markdown]
# Helpful for bagging xgb models: https://github.com/andyh47/higgs

# %% [markdown]
# - Model0 is reaching 0.9683+ after 1750 rounds. Should verify this model's score on the LB
# - Model0 peaked at 0.968262 after round 1999 (didn't hit early stop of 100)
# - Model1 peak around 0.9684 then drops on the test data, maybe overfitting on train set
# - Model2 peak around 0.9682
# - Model3 peak around 0.9682
# - Model4 peak around 0.9682

# %%
def predict(models, data):
    predicted = np.empty((data.num_row(),len(models)))
    predicted[:] = np.NAN
    for i,m in enumerate(models):
        print('\rPredicting {} of {}'.format(i+1,len(models)),end='')
        predicted[:,i] = m.predict(data)
    return np.apply_along_axis(np.mean,1,predicted)

# %%
xg_train = xgb.DMatrix( X.as_matrix(), label=Y)
p_train = predict(models, xg_train)
p_test = predict(models, xg_test)
# Out:
# Predicting 13 of 13

# %%
train_acc = sum(Y == np.round(p_train))/len(p_train)
test_acc = sum(train_labels[N:] == np.round(p_test))/len(p_test)
print(len(models))
print( train_acc )
print( test_acc)
# Out:
# 13
# 0.937271228114
# 0.927749654855

# %% [markdown]
# ~0.968 each for 29 models: 0.96746 LB

# %%
xg_pred = xgb.DMatrix( test_dat.as_matrix())

pred = predict(models, xg_pred)
sample = pd.read_csv('sample_submission.csv')
sample.QuoteConversion_Flag = pred
sample.to_csv('bagging_submission03.csv', index=False)
# Out:
# Predicting 13 of 13

# %%
xg_pred = xgb.DMatrix( test_dat.as_matrix())

pred = models[1].predict(xg_pred)
sample = pd.read_csv('sample_submission.csv')
sample.QuoteConversion_Flag = pred
sample.to_csv('ensemble_model1.csv', index=False)

# %%
j

# %%
for root, dirs, files in os.walk("/mydir"):
    for file in files:
        if file.endswith(".txt"):
             print(os.path.join(root, file))
